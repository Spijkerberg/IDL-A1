# %%
import numpy as np
import pandas as pd 

csv = pd.read_csv(r"C:\Users\timvd\Documents\Uni 2023-2024\IDL\IDL-A1\individual_solns\IDL_A1_convolution_with_BN.csv")
kwargs = np.array(csv['Kwargs'])
etas = [element[-6:-1] for element in kwargs]
csv = csv.drop('Kwargs',axis='columns')
csv['Learning rate'] = etas
csv = csv.rename(columns={"Name":"Optimizer","Batch_size":"Batch size"})
cols = csv.columns.tolist()
cols = [cols[0],cols[-1],*cols[1:-1]]
csv = csv[cols]
csv = csv.round({'Accuracy':3})
csv.sort_values('Accuracy',inplace=True,ascending=False,ignore_index=True)
csv.to_csv(r"C:\Users\timvd\Documents\Uni 2023-2024\IDL\IDL-A1\individual_solns\IDL_A1_convolution_with_BN_forLatex.csv",index=False)
csv
# Out:
#    Optimizer Learning rate  Batch size  Epochs  Accuracy
# 0      Nadam         0.001         256      10     0.872
# 1      Nadam         0.001         128      10     0.862
# 2      Nadam         0.001         512      10     0.862
# 3     Adamax         0.001          64      10     0.851
# 4       Adam         0.001          64      10     0.850
# 5       Adam         0.001         256      10     0.838
# 6      Nadam         0.001          64      10     0.838
# 7       Adam         0.001         512      10     0.828
# 8       Adam         0.001         128      10     0.822
# 9     Adamax         0.001         128      10     0.820
# 10    Adamax         0.001         512      10     0.801
# 11    Adamax         0.001         256      10     0.795

# %%
csv = pd.read_csv(r"C:\Users\timvd\Documents\Uni 2023-2024\IDL\IDL-A1\individual_solns\IDL_A1_convolution_default (1).csv")
kwargs = np.array(csv['Kwargs'])
etas = [element[-6:-1] for element in kwargs]
csv = csv.drop('Kwargs',axis='columns')
csv['Learning rate'] = etas
csv = csv.rename(columns={"Name":"Optimizer","Batch_size":"Batch size"})
cols = csv.columns.tolist()
cols = [cols[0],cols[-1],*cols[1:-1]]
csv = csv[cols]
csv = csv.round({'Accuracy':3})
csv.sort_values('Accuracy',inplace=True,ascending=False,ignore_index=True)
csv.to_csv(r"C:\Users\timvd\Documents\Uni 2023-2024\IDL\IDL-A1\individual_solns\IDL_A1_convolution_default_forLatex.csv",index = False)
csv
# Out:
#    Optimizer Learning rate  Batch size  Epochs  Accuracy
# 0     Adamax         .0005         128      10     0.905
# 1     Adamax         0.001         256      10     0.903
# 2     Adamax         0.001         512      20     0.900
# 3     Adamax         .0005          64      10     0.898
# 4       Adam         0.001         128      10     0.896
# ..       ...           ...         ...     ...       ...
# 57       SGD         0.001         128       5     0.325
# 58  Adadelta         0.001          64       5     0.301
# 59  Adadelta         0.001         512       5     0.149
# 60  Adadelta         0.001         256       5     0.109
# 61  Adadelta         0.001         128       5     0.101
#
# [62 rows x 5 columns]
